# %% [markdown]
# #### Description
#
# - geo_level_1_id, geo_level_2_id, geo_level_3_id (type: categorical): geographic region in which building exists, from largest (level 1) to most specific sub-region (level 3).
# - count_floors_pre_eq (type: int): number of floors in the building before the earthquake.
# - age_building (type: int): age of the building.
# - plinth_area_sq_ft_percentage (type: float): plinth area of the building described as the percentage of all buildings' areas.
# - height_ft_pre_eq_percentage (type: float): height of the building described as the percentage of all buildings' heights.
# - land_surface_condition (type: categorical): surface condition of the land where the building was built. Possible values: d502, 808e, 2f15.
# - foundation_type (type: categorical): type of foundation used while building. Possible values: 337f, 858b, 6c3e, 467b, bb5f.
# - roof_type (type: categorical): type of roof used while building. Possible values: 7e76, e0e2, 67f9.
# - ground_floor_type (type: categorical): type of the ground floor. Possible values: b1b4, b440, 467b, e26c, bb5f.
# - other_floor_type (type: categorical): type of constructions used in higher than the ground floors (except of roof). Possible values: f962, 9eb0, 441a, 67f9.
# - position (type: categorical): position of the building. Possible values: 3356, bfba, bcab, 1787.
# - plan_configuration (type: categorical): building plan configuration. Possible values: a779, 84cf, 8e3f, d2d9, 3fee, 6e81, 0448, 1442, cb88.
# - has_superstructure_adobe_mud (type: binary): flag variable that indicates if the s superstructure was made of Adobe/Mud.
# - has_superstructure_mud_mortar_stone (type: binary): flag variable that indicates if the superstructure was made of Mud Mortar - Stone.
# - has_superstructure_stone_flag (type: binary): flag variable that indicates if the superstructure was made of Stone.
# - has_superstructure_cement_mortar_stone (type: binary): flag variable that indicates if the superstructure was made of Cement Mortar - Stone.
# - has_superstructure_mud_mortar_brick (type: binary): flag variable that indicates if the superstructure was made of Mud Mortar - Brick.
# - has_superstructure_cement_mortar_brick (type: binary): flag variable that indicates if the superstructure was made of Cement Mortar - Brick.
# - has_superstructure_timber (type: binary): flag variable that indicates if the superstructure was made of Timber.
# - has_superstructure_bamboo (type: binary): flag variable that indicates if the superstructure was made of Bamboo.
# - has_superstructure_rc_non_engineered (type: binary): flag variable that indicates if the superstructure was made of non-engineered reinforced concrete.
# - has_superstructure_rc_engineered (type: binary): flag variable that indicates if the superstructure was made of engineered reinforced concrete.
# - has_superstructure_other (type: binary): flag variable that indicates if the superstructure was made of any other material.
# - legal_ownership_status (type: categorical): legal ownership status of the land where building was built. Possible values: c8e1, cae1, ab03, bb5f.
# - count_families (type: float): number of families that live in the building.
# - has_secondary_use (type: binary): flag variable that indicates if the building was used for any secondary purpose.
# - has_secondary_use_agriculture (type: binary): flag variable that indicates if the building was used for agricultural purposes.
# - has_secondary_use_hotel (type: binary): flag variable that indicates if the building was used as a hotel.
# - has_secondary_use_rental (type: binary): flag variable that indicates if the building was used for rental purposes.
# - has_secondary_use_institution (type: binary): flag variable that indicates if the building was used as a location of any institution.
# - has_secondary_use_school (type: binary): flag variable that indicates if the building was used as a school.
# - has_secondary_use_industry (type: binary): flag variable that indicates if the building was used for industrial purposes.
# - has_secondary_use_health_post (type: binary): flag variable that indicates if the building was used as a health post.
# - has_secondary_use_gov_office (type: binary): flag variable that indicates if the building was used fas a government office.
# - has_secondary_use_use_police (type: binary): flag variable that indicates if the building was used as a police station.
# - has_secondary_use_other (type: binary): flag variable that indicates if the building was secondarily used for other purposes.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from pandas_profiling import ProfileReport as pp

# %matplotlib inline
pd.set_option("display.max_rows",10000)
pd.set_option("display.max_columns",40)

# %%
df = pd.read_csv("capstone_earthquake_data_set.csv")

# %%
df.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0          765               8             501            3237
# 1         9470               7             288            1819
# 2        14461              14              36             838
# 3         9317               8              81             805
# 4        15941              23             380            4266
#
#    count_floors_pre_eq  age  area  height land_surface_condition  \
# 0                    2   25    33       4                   d502
# 1                    3   15    28       5                   d502
# 2                    1   20    37       2                   d502
# 3                    2    5    18       3                   d502
# 4                    3    0    39       6                   d502
#
#   foundation_type roof_type ground_floor_type other_floor_type position  \
# 0            337f  7.00E+76              b1b4             f962     3356
# ...

# %%
df.tail()
# Out:
#       building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 9995        10955              27            1079           10612
# 9996        17289               7             215            3259
# 9997         5192              12              24             330
# 9998        12172              12              13             248
# 9999          235               9               2             314
#
#       count_floors_pre_eq  age  area  height land_surface_condition  \
# 9995                    2   10    49       5                   d502
# 9996                    3   50    34       5                   d502
# 9997                    2   15    42       5                   d502
# 9998                    2   20    88       6                   d502
# 9999                    2   40    14       3                   d502
#
#      foundation_type roof_type ground_floor_type other_floor_type position  \
# 9995            337f      e0e2              467b             f962     3356
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 40 columns):
# building_id                               10000 non-null int64
# geo_level_1_id                            10000 non-null int64
# geo_level_2_id                            10000 non-null int64
# geo_level_3_id                            10000 non-null int64
# count_floors_pre_eq                       10000 non-null int64
# age                                       10000 non-null int64
# area                                      10000 non-null int64
# height                                    10000 non-null int64
# land_surface_condition                    10000 non-null object
# foundation_type                           10000 non-null object
# roof_type                                 10000 non-null object
# ground_floor_type                         10000 non-null object
# other_floor_type                          10000 non-null object
# ...

# %%
for col in ['building_id','geo_level_1_id','geo_level_2_id','geo_level_3_id','damage_grade']:
    df[col] = df[col].astype('object')

# %%
df.describe(include='all')
# Out:
#         building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# count       10000.0         10000.0         10000.0         10000.0
# unique      10000.0            31.0          1137.0          5172.0
# top         16383.0             0.0             0.0             0.0
# freq            1.0           903.0           157.0            24.0
# mean            NaN             NaN             NaN             NaN
# std             NaN             NaN             NaN             NaN
# min             NaN             NaN             NaN             NaN
# 25%             NaN             NaN             NaN             NaN
# 50%             NaN             NaN             NaN             NaN
# 75%             NaN             NaN             NaN             NaN
# max             NaN             NaN             NaN             NaN
#
#         count_floors_pre_eq           age          area        height  \
# count          10000.000000  10000.000000  10000.000000  10000.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 40 columns):
# building_id                               10000 non-null object
# geo_level_1_id                            10000 non-null object
# geo_level_2_id                            10000 non-null object
# geo_level_3_id                            10000 non-null object
# count_floors_pre_eq                       10000 non-null int64
# age                                       10000 non-null int64
# area                                      10000 non-null int64
# height                                    10000 non-null int64
# land_surface_condition                    10000 non-null object
# foundation_type                           10000 non-null object
# roof_type                                 10000 non-null object
# ground_floor_type                         10000 non-null object
# other_floor_type                          10000 non-null object
# ...

# %%
df.shape
# Out:
# (10000, 40)

# %%
df['building_id'].value_counts()
# Out:
# 16383    1
# 13737    1
# 4520     1
# 4515     1
# 4513     1
# 4512     1
# 4509     1
# 4508     1
# 4507     1
# 4503     1
# 4524     1
# 4500     1
# 18448    1
# 4498     1
# 4496     1
# 4495     1
# 1713     1
# 4489     1
# 4521     1
# 4525     1
# 4720     1
# 3172     1
# 4557     1
# 4556     1
# 4554     1
# 4552     1
# 4551     1
# 4548     1
# 18855    1
# 4541     1
# 18451    1
# 4539     1
# 4536     1
# 4534     1
# 4533     1
# 4531     1
# 4529     1
# 4527     1
# 4486     1
# 4483     1
# 4482     1
# 4435     1
# 4448     1
# 16881    1
# 4446     1
# 4444     1
# 4441     1
# 4440     1
# 5908     1
# 4433     1
# 4481     1
# 4428     1
# 4420     1
# 4419     1
# 493      1
# 4417     1
# 4415     1
# 4411     1
# 18902    1
# 4450     1
# 4452     1
# 4453     1
# 4478     1
# 4477     1
# 4475     1
# 4472     1
# 4470     1
# 4466     1
# 4465     1
# 4463     1
# 4462     1
# 4460     1
# 4459     1
# 4458     1
# 4456     1
# 4455     1
# ...

# %%
df['geo_level_1_id'].value_counts()
# Out:
# 0     903
# 2     860
# 3     843
# 1     842
# 5     751
# 4     730
# 6     683
# 7     617
# 8     559
# 9     523
# 10    367
# 11    304
# 12    292
# 13    256
# 14    194
# 15    147
# 16    147
# 17    134
# 20    121
# 18    102
# 19    102
# 21     98
# 22     97
# 23     90
# 24     74
# 26     47
# 25     41
# 27     37
# 28     19
# 29     13
# 30      7
# Name: geo_level_1_id, dtype: int64

# %%
df['geo_level_2_id'].value_counts()
# Out:
# 0       157
# 1        99
# 2        94
# 3        81
# 5        75
# 8        71
# 9        68
# 7        63
# 4        63
# 12       61
# 6        60
# 10       52
# 13       52
# 23       51
# 11       49
# 29       47
# 14       46
# 34       45
# 17       44
# 21       44
# 22       44
# 24       43
# 18       43
# 25       42
# 15       39
# 20       38
# 16       38
# 19       37
# 28       35
# 30       35
# 31       33
# 45       33
# 26       33
# 42       32
# 41       32
# 53       31
# 39       31
# 33       31
# 50       31
# 32       31
# 51       30
# 37       28
# 27       27
# 56       26
# 238      25
# 61       25
# 84       25
# 46       25
# 90       24
# 87       24
# 106      24
# 43       24
# 82       24
# 178      24
# 48       24
# 78       24
# 202      24
# 64       23
# 49       23
# 44       23
# 149      23
# 60       23
# 100      22
# 95       22
# 117      22
# 101      22
# 89       22
# 102      22
# 312      22
# 85       22
# 171      22
# ...

# %%
df['geo_level_3_id'].value_counts()
# Out:
# 0        24
# 1        24
# 7        24
# 2        21
# 3        21
# 4        18
# 5        18
# 14       17
# 8        14
# 11       14
# 12       14
# 16       13
# 10       13
# 9        12
# 18       12
# 42       11
# 15       11
# 33       11
# 37       10
# 25       10
# 278      10
# 28       10
# 29       10
# 6        10
# 129       9
# 112       9
# 315       9
# 87        9
# 78        9
# 53        9
# 51        9
# 44        9
# 39        9
# 149       9
# 13        9
# 24        9
# 546       9
# 82        8
# 192       8
# 169       8
# 56        8
# 198       8
# 79        8
# 52        8
# 27        8
# 36        8
# 21        8
# 97        8
# 177       8
# 178       8
# 229       8
# 880       8
# 32        8
# 26        8
# 93        8
# 361       7
# 572       7
# 380       7
# 189       7
# 309       7
# 556       7
# 952       7
# 200       7
# 218       7
# 98        7
# 101       7
# 105       7
# 106       7
# 257       7
# 965       7
# 228       7
# ...

# %%
df['count_floors_pre_eq'].value_counts()
# Out:
# 2    5923
# 3    2235
# 1    1521
# 4     224
# 5      87
# 6       8
# 7       1
# 9       1
# Name: count_floors_pre_eq, dtype: int64

# %%
df['age'].value_counts()
# Out:
# 10     1481
# 15     1373
# 5      1279
# 20     1236
# 25      999
# 0       984
# 30      688
# 40      405
# 35      375
# 50      298
# 45      185
# 60      152
# 80      111
# 55       82
# 70       66
# 100      62
# 65       45
# 995      40
# 85       40
# 90       38
# 75       21
# 95       16
# 110       5
# 150       5
# 120       5
# 105       3
# 200       2
# 180       1
# 170       1
# 190       1
# 125       1
# Name: age, dtype: int64

# %%
df['area'].value_counts()
# Out:
# 28     621
# 37     469
# 42     451
# 32     428
# 35     372
# 24     365
# 29     328
# 26     302
# 23     291
# 31     289
# 33     260
# 30     260
# 39     236
# 18     199
# 46     194
# 56     184
# 22     184
# 44     183
# 36     181
# 14     180
# 20     177
# 25     176
# 34     168
# 21     164
# 27     155
# 41     150
# 19     133
# 38     132
# 40     132
# 51     122
# 16     115
# 47     114
# 50     100
# 60      94
# 48      93
# 43      91
# 17      91
# 65      81
# 45      81
# 49      75
# 52      74
# 63      69
# 70      67
# 57      65
# 58      65
# 74      64
# 53      61
# 54      60
# 13      50
# 15      50
# 59      48
# 67      42
# 64      40
# 55      40
# 79      39
# 11      37
# 84      34
# 61      31
# 112     28
# 9       27
# 93      26
# 12      26
# 62      24
# 10      21
# 71      20
# 72      19
# 68      18
# 92      18
# 75      18
# 69      17
# 88      17
# 95      16
# 80      16
# 89      15
# 73      14
# 78      14
# ...

# %%
df['height'].value_counts()
# Out:
# 5     2820
# 4     2298
# 3     1507
# 6     1355
# 2      813
# 7      561
# 8      216
# 9      144
# 1      123
# 10      53
# 11      43
# 12      42
# 14      11
# 15       7
# 13       4
# 30       1
# 24       1
# 16       1
# Name: height, dtype: int64

# %%
df['land_surface_condition'].value_counts()
# Out:
# d502    8311
# 808e    1342
# 2f15     347
# Name: land_surface_condition, dtype: int64

# %%
df['foundation_type'].value_counts()
# Out:
# 337f    8489
# 858b     587
# 6c3e     504
# 467b     372
# bb5f      48
# Name: foundation_type, dtype: int64

# %%
df['roof_type'].value_counts()
# Out:
# 7.00E+76    7007
# e0e2        2414
# 67f9         579
# Name: roof_type, dtype: int64

# %%
df['ground_floor_type'].value_counts()
# Out:
# b1b4    8118
# b440     963
# 467b     875
# e26c      34
# bb5f      10
# Name: ground_floor_type, dtype: int64

# %%
df['other_floor_type'].value_counts()
# Out:
# f962    6412
# 9eb0    1677
# 441a    1496
# 67f9     415
# Name: other_floor_type, dtype: int64

# %%
df['position'].value_counts()
# Out:
# 3356    7792
# bfba    1623
# bcab     477
# 1787     108
# Name: position, dtype: int64

# %%
df['plan_configuration'].value_counts()
# Out:
# a779        9603
# 84cf         200
# 8e3f         158
# d2d9          15
# 3fee          13
# 6.00E+81       6
# 1442           2
# 448            2
# cb88           1
# Name: plan_configuration, dtype: int64

# %%
df['has_superstructure_adobe_mud'].value_counts()
# Out:
# 0    9103
# 1     897
# Name: has_superstructure_adobe_mud, dtype: int64

# %%
df['has_superstructure_mud_mortar_stone'].value_counts()
# Out:
# 1    7626
# 0    2374
# Name: has_superstructure_mud_mortar_stone, dtype: int64

# %%
df['has_superstructure_stone_flag'].value_counts()
# Out:
# 0    9701
# 1     299
# Name: has_superstructure_stone_flag, dtype: int64

# %%
df['has_superstructure_cement_mortar_stone'].value_counts()
# Out:
# 0    9810
# 1     190
# Name: has_superstructure_cement_mortar_stone, dtype: int64

# %%
df['has_superstructure_mud_mortar_brick'].value_counts()
# Out:
# 0    9312
# 1     688
# Name: has_superstructure_mud_mortar_brick, dtype: int64

# %%
df['has_superstructure_cement_mortar_brick'].value_counts()
# Out:
# 0    9275
# 1     725
# Name: has_superstructure_cement_mortar_brick, dtype: int64

# %%
df['has_superstructure_timber'].value_counts()
# Out:
# 0    7439
# 1    2561
# Name: has_superstructure_timber, dtype: int64

# %%
df['has_superstructure_bamboo'].value_counts()
# Out:
# 0    9123
# 1     877
# Name: has_superstructure_bamboo, dtype: int64

# %%
df['has_superstructure_rc_non_engineered'].value_counts()
# Out:
# 0    9600
# 1     400
# Name: has_superstructure_rc_non_engineered, dtype: int64

# %%
df['has_superstructure_rc_engineered'].value_counts()
# Out:
# 0    9862
# 1     138
# Name: has_superstructure_rc_engineered, dtype: int64

# %%
df['has_superstructure_other'].value_counts()
# Out:
# 0    9859
# 1     141
# Name: has_superstructure_other, dtype: int64

# %%
df['legal_ownership_status'].value_counts()
# Out:
# c8e1    9627
# cae1     214
# ab03      98
# bb5f      61
# Name: legal_ownership_status, dtype: int64

# %%
df['count_families'].value_counts()
# Out:
# 1    8672
# 0     803
# 2     433
# 3      70
# 4      16
# 5       3
# 6       2
# 7       1
# Name: count_families, dtype: int64

# %%
df['has_secondary_use'].value_counts()
# Out:
# 0    8914
# 1    1086
# Name: has_secondary_use, dtype: int64

# %% [markdown]
# ### Data Visualization

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="geo_level_1_id",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="geo_level_2_id",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="geo_level_3_id",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="count_floors_pre_eq",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="age",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="area",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="height",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="land_surface_condition",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="foundation_type",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="roof_type",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="ground_floor_type",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="other_floor_type",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="position",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="plan_configuration",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="has_superstructure_adobe_mud",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="has_superstructure_mud_mortar_stone",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="has_superstructure_stone_flag",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="has_superstructure_cement_mortar_stone",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="has_superstructure_mud_mortar_brick",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="has_superstructure_cement_mortar_brick",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="has_superstructure_timber",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="has_superstructure_bamboo",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="has_superstructure_rc_non_engineered",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="has_superstructure_rc_engineered",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="has_superstructure_other",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="legal_ownership_status",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="count_families",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="has_secondary_use",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="has_secondary_use_agriculture",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="has_secondary_use_hotel",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="has_secondary_use_rental",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="has_secondary_use_institution",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="has_secondary_use_school",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="has_secondary_use_industry",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="has_secondary_use_health_post",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="has_secondary_use_gov_office",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="has_secondary_use_use_police",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="has_secondary_use_other",hue="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.barplot(x="count_floors_pre_eq",y="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.barplot(x="age",y="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.barplot(x="area",y="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.barplot(x="height",y="damage_grade",data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Feature Selection

# %% [markdown]
# **Remove** building_id , geo_level_1_id, geo_level_2_id, geo_level_3_id, area, roof_type,
# ground_floor_type, other_floor_type,position, plan_configuration, legal_ownership_status,
# count_families, has_secondary_use, has_secondary_use_agriculture, has_secondary_use_hotel,
# has_secondary_use_rental, has_secondary_use_institution, has_secondary_use_school,
# has_secondary_use_industry, has_secondary_use_health_post, has_secondary_use_gov_office,
# has_secondary_use_use_police, has_secondary_use_other

# %%
pp(df)
# Out:
# ...
# Report generated with <a href="https://github.com/pandas-profiling/pandas-profiling">pandas-profiling</a>.
