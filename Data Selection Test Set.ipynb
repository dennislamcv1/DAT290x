# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
pd.set_option("display.max_rows",10000)
pd.set_option("display.max_columns",40)

from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("test_values.csv")

# %%
df.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       300051              17             596           11307
# 1        99355               6             141           11987
# 2       890251              22              19           10044
# 3       745817              26              39             633
# 4       421793              17             289            7970
#
#    count_floors_pre_eq  age  area  height land_surface_condition  \
# 0                    3   20     7       6                   d502
# 1                    2   25    13       5                   d502
# 2                    2    5     4       5                   d502
# 3                    1    0    19       3                   d502
# 4                    3   15     8       7                   d502
#
#   foundation_type roof_type ground_floor_type other_floor_type position  \
# 0            337f      808e                 f                q        s
# ...

# %%
df.shape
# Out:
# (86868, 39)

# %% [markdown]
# ### Remove unwanted features

# %%
df1 = df.drop(['building_id','geo_level_1_id','geo_level_2_id','geo_level_3_id','area',
              'roof_type','ground_floor_type','other_floor_type','position','plan_configuration',
              'legal_ownership_status','count_families','has_secondary_use',
              'has_secondary_use_agriculture', 'has_secondary_use_hotel', 'has_secondary_use_rental', 
              'has_secondary_use_institution','has_secondary_use_school', 'has_secondary_use_industry',
              'has_secondary_use_health_post', 'has_secondary_use_gov_office','has_secondary_use_use_police', 
              'has_secondary_use_other'], axis=1)

# %%
df1.head()
# Out:
#    count_floors_pre_eq  age  height land_surface_condition foundation_type  \
# 0                    3   20       6                   d502            337f
# 1                    2   25       5                   d502            337f
# 2                    2    5       5                   d502            337f
# 3                    1    0       3                   d502            337f
# 4                    3   15       7                   d502            337f
#
#    has_superstructure_adobe_mud  has_superstructure_mud_mortar_stone  \
# 0                             0                                    1
# 1                             0                                    1
# 2                             0                                    1
# 3                             0                                    0
# 4                             0                                    1
#
#    has_superstructure_stone_flag  has_superstructure_cement_mortar_stone  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86868 entries, 0 to 86867
# Data columns (total 16 columns):
# count_floors_pre_eq                       86868 non-null int64
# age                                       86868 non-null int64
# height                                    86868 non-null int64
# land_surface_condition                    86868 non-null object
# foundation_type                           86868 non-null object
# has_superstructure_adobe_mud              86868 non-null int64
# has_superstructure_mud_mortar_stone       86868 non-null int64
# has_superstructure_stone_flag             86868 non-null int64
# has_superstructure_cement_mortar_stone    86868 non-null int64
# has_superstructure_mud_mortar_brick       86868 non-null int64
# has_superstructure_cement_mortar_brick    86868 non-null int64
# has_superstructure_timber                 86868 non-null int64
# has_superstructure_bamboo                 86868 non-null int64
# ...

# %%
df1.shape
# Out:
# (86868, 16)

# %%
#save to csv
#df1.to_csv("testselect.csv",index=False)

# %%
df1 = pd.read_csv("testselect.csv")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86868 entries, 0 to 86867
# Data columns (total 16 columns):
# count_floors_pre_eq                       86868 non-null int64
# age                                       86868 non-null int64
# height                                    86868 non-null int64
# land_surface_condition                    86868 non-null object
# foundation_type                           86868 non-null object
# has_superstructure_adobe_mud              86868 non-null int64
# has_superstructure_mud_mortar_stone       86868 non-null int64
# has_superstructure_stone_flag             86868 non-null int64
# has_superstructure_cement_mortar_stone    86868 non-null int64
# has_superstructure_mud_mortar_brick       86868 non-null int64
# has_superstructure_cement_mortar_brick    86868 non-null int64
# has_superstructure_timber                 86868 non-null int64
# has_superstructure_bamboo                 86868 non-null int64
# ...

# %%
df1['land_surface_condition'].value_counts()
# Out:
# d502    72180
# 808e    11885
# 2f15     2803
# Name: land_surface_condition, dtype: int64

# %%
df1['foundation_type'].value_counts()
# Out:
# 337f    73178
# 858b     4930
# 6c3e     4648
# 467b     3603
# bb5f      509
# Name: foundation_type, dtype: int64

# %% [markdown]
# ### We will combine with train set to do whole encoding
